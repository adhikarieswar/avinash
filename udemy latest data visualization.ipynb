# %%
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
udemy=pd.read_csv(r'C:\Users\DELL\Downloads\udemy_courses.csv')

# %%
udemy
np.random.randint(10,50,size=23)
# Out:
# array([47, 16, 15, 42, 23, 17, 26, 45, 19, 43, 20, 33, 32, 48, 19, 20, 15,
#        42, 42, 36, 13, 27, 14])

# %%
# check null values in dataset.
udemy.isnull().sum()
# Out:
# course_id              0
# course_title           0
# url                    0
# is_paid                0
# price                  0
# num_subscribers        0
# num_reviews            0
# num_lectures           0
# level                  0
# content_duration       0
# published_timestamp    0
# subject                0
# dtype: int64

# %%
# check for duplicate values

# %%
udemy.duplicated().any()
# Out:
# True

# %%
import statistics as stats
x=[1,2,34,56,78,98]
stats.mean(x)
# Out:
# 44.833333333333336

# %%
def ma(n):
    return n+6
n=[2,4,5,7,8,9]
z=list(map(ma,n))
z
# Out:
# [8, 10, 11, 13, 14, 15]

# %%
sns.countplot(udemy['subject'])
plt.xlabel('subjects', fontsize=12)
plt.ylabel('counts of courses',fontsize=13)
plt.xticks(rotation=45)
plt.show()
sns.countplot(udemy['level'])
plt.xlabel('count',fontsize=10)
plt.ylabel('no of courses',fontsize=10)
plt.xlabel('count',fontsize=12)
plt.xlabel('count', fontsize=12)
plt.ylabel('no of courses', fontsize=10)
plt.xticks(rotation=34)
plt.show()
# Out:
# f:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# f:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(udemy['num_subscribers'])
# Out:
# f:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='num_subscribers', ylabel='count'>

# %%
# find out no of courses per subject.
udemy.head()
udemy.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
sns.countplot(udemy['subject'])
sns.countplot(udemy['subject'])
sns.countplot(udemy['subject'])
plt.xlabel('types of subjects',fontsize=7)
plt.ylabel('count of courses', fontsize=7)
plt.xticks(rotation=48)
# Out:
# f:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# f:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# f:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
# for which level udemy courses providing courses
udemy.head(3)
udemy.columns
udemy.head()
udemy['']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# f:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# f:\Users\DELL\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# f:\Users\DELL\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ''
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
        
sns.countplot(udemy['level'])
plt.xlabel('levels',fontsize=10)
plt.ylabel('count',fontsize=10)
plt.xticks(rotation=23)
plt.show()

# %%
# display the count of paid and free courses
udemy.columns
udemy.head(1)
udemy['is_paid'].value_counts()

# %%
`
udemy.head()
udemy.groupby('is_paid').max('num_lectures')['num_lectures']

# %%
# display the number of subscribers for paid vs free courses.
udemy.columns
udemy.groupby('is_paid').sum('num_subscribers')['num_subscribers']

# %%
# which level has the highest number of subscribers
udemy.columns
udemy.head(3)
udemy.columns

udemy.groupby('level').mean('num_subscribers').sort_values(by='num_subscribers',ascending=False).head(1)
udemy['level'].value_counts()

# %%
u7

# %%
# find most popular course title.
udemy.head(2)

udemy[udemy['num_subscribers'].max()==udemy['num_subscribers']]['course_title']

# %%
# display 10 most popular course as per number of subscribers.
udemy.head(1)
udemy[udemy['num_subscribers'].mean()==udemy['num_subscribers']]['course_title'].head(2)

# %%
udemy.head(2)
index=udemy['num_subscribers'].sort_values(ascending=False).head(10).index
udemy.iloc[index]['course_title']

# %%
index=udemy['num_subscribers'].sort_values(ascending=False).head(10).index
udemy.iloc[index]['course_title']

# %%
# display the number of subscribers for paid vs free courses.
udemy

# %%
# display 10 most popular course as per number of subscribers.
udemy.head(10)
udemy.groupby('course_title').mean('num_subscribers').sort_values(by=['num_subscribers'],ascending=False).head(10)
udemy['num_subscribers'].max()
sns.barplot(x='course_title',y='num_subscribers',data=udemy)

# %%
# find most popular course title.
udemy.head(2)
index=udemy['num_subscribers'].sort_values(ascending=False).head(1).index
udemy.iloc[index]

# %%
# display 10 most popular course as per number of subscribers.
index=udemy['num_subscribers'].sort_values(ascending=False).head(10).index
index
udemy.iloc[index]['']

# %%
# display 10 most popular course as per number of subscribers.
udemy.head(1)
index=udemy['num_subscribers'].sort_values(ascending=False).head(10).index
index

# %%
# most popular course title.
udemy.head(1)
udemy.groupby('course_title').mean('num_subscribers').sort_values(by=['num_subscribers'],ascending=False).head(1)

# %%
# which level has the highest number of subscribers
udemy.head(1)
udemy.groupby('level').sum('num_subscribers')

# %%
# display 10 most popular course as per number of subscribers.
udemy.head(2)
index=udemy['num_subscribers'].sort_values(ascending=False).head(10).index
udemy.iloc[index]['course_title']

# %%
# find the course having highest number of reviews.
udemy.head(2)
udemy.columns
udemy[udemy['num_reviews'].max()==udemy['num_reviews']]['course_title']

# %%
# does price effect the number of reviews.

# %%
udemy.head(1)
udemy[udemy['num_reviews'].max()==udemy['num_reviews']]['course_title']

# %%
# display 10 most popular  python courses.
udemy.head(45)
udemy.columns
udemy['num_subscribers'].dtypes
udemy[udemy['num_subscribers'].mean()==udemy['num_subscribers']]['course_title']

# %%
# find total number of courses related to python.
udemy.head(1)
udemy.head(1)
udemy[udemy['course_title'].str.contains('python')==udemy['course_title']]

# %%
diabetes

# %%
x= diabetes.iloc[:,0:8]
x

# %%
y=diabetes.iloc[:,7]
y

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=1/3,randomstate=45)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.45)

# %%
udemy[udemy['course_title'].str.contains('python')==udemy['course_title']]

# %%
len(udemy[udemy['course_title'].str.contains('python',case=False)])

# %%
udemy.head(4)

# %%
udemy

# %%
udemy.groupby['is_paid'].filter(lambda x:x['price'].max()>100)

# %%
# check if  price is greater than 150 then course will be in risk
udemy.head()

# %%
def check_risk(p):
    flag=p['price']>100
    udemy['risk']=flag
    return p

# %%
udemy1=udemy.groupby('level').apply(check_risk)

# %%
udemy1.columns

# %%
udemy.loc[udemy1['risk']==True]

# %%
def check(p):
    flag=(p['content_duration'])<2.5   # if the condition is true it will give true otherwise false 
    p['risk']=flag
    return p

# %%
udemy.columns

# %%
def ud(p):
    flag=p['content_duration']<2.00
    p['risky']=flag
    return p

# %%
tp=udemy.groupby('is_paid').apply(ud)

# %%
tp[tp['risky']==True]

# %%
udemy.columns

# %%
udemy.loc[udemy['num_reviews']>=2.00]['course_title']

# %%
udemy[udemy['is_paid']==False]

# %%
udemy.duplicated().any()

# %%
udemy.columns

# %%
udemy.columns

# %%
# how to sort values using group by of it 
udemy['course_title'].count()

# %%
udemy.groupby('level')['num_reviews'].count().sort_values(ascending=True)

# %%
udemy.sort_values(['num_reviews'],ascending=[False])
udemy['num_reviews'].sort_values()

# %%
udemy['content_duration']

# %%
import datetime 
udemy.columns

# %%
type('published_timestamp')

# %%
p=datetime.datetime.now()

# %%
type(p)

# %%
#.diff function gives difference between before and current value in seconds
udemy.columns

# %%
udemy3=udemy['level'].value_counts()

# %%
x=udemy3.index

# %%
x
y=udemy3

# %%
plt.bar(x,y)

# %%
udemy6=udemy['level'].value_counts()

# %%
udemy6.index

# %%
udemy6

# %%
t=udemy['level'].value_counts()

# %%
x=t.index

# %%
y=t

# %%
plt.bar(x,y)

# %%
plt.figure(figsize=(12,18)) # figsize gives tuple it shows x size in inches and y size in inches

# %%
plt.bar(x,y,width=0.6)# y lo value counts antha apply chesestamu dentlo
# width gives width of barplot that is plotted

# %%
udemy.columns

# %%
udemy['course_id'].value_counts

# %%
plt.xticks(rotation=45,fontsize=14)

# %%
plt.figure(figsize=(12,14))

# %%
plt.figure(figsize=(12,13))

# %%
plt.bar(x,y)

# %%
plt.xticks(rotation=45)

# %%
plt.bar(x,y)
plt.xticks(rotation=90,fontsize=14)
plt.xlabel("Levels",fontsize=7)
plt.ylabel("count",fontsize=7)
plt.title("count of levels")
plt.title('axis of it')# xticks for xticks labelling  
plt.show()

# %%
plt.bar(x,y,width=0.4,color='orange')
plt.xlabel('levels')
plt.ylabel('count')
plt.xticks(rotation=90,fontsize=13)
plt.xlabel("count")
plt.ylabel("no of rotations")
plt.title('count per genre',fontsize=14)
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
udemy.columns

# %%
t=udemy['level'].value_counts()
x=t.index
x
y=t

# %%
plt.bar(x,y)
plt.xlabel('levels')
plt.ylabel('count')
plt.xticks(rotation=90,fontsize=14)
plt.title('count genre')

# %%
plt.bar(x,y)

# %%
p

# %%
p

# %%
s=sns.countplot(data=udemy,x='level',order=udemy['level'].value_counts().index)# it will follow the order of it based on 
#value counts function the order it is following

# %%
import seaborn as sns

# %%
sns.countplot(data=udemy,x='level',order=udemy['level'].value_counts().index)
sns.countplot(data=udemy,x='level',order=udemy['level'].value_counts().index)

# %%
import matplotlib.pyplot as plt

# %%
sns.countplot(data=ude
              
x=udemy['level'])
udemy.columns

# %%
plt.hist(udemy['level'],bins=4)

# %%
udemy['level'].value_counts() # plt.hist gives count of it  for each values will be displayed for it u should have to give dataframe and column of it

# %%
plt.bar(x)

# %%
sns.histplot(udemy['level'],bins=2)

# %%
import matplotlib.pyplot as plt
plt.bar(x,y)

# %%
plt.hist(udemy['level'],bins=3)

# %%
plt.hist(udemy['level'],bins=4) # we will get the combination of it

# %%
sns.histplot(udemy['level'],bins=3)

# %%
sns.histplot(udemy['level'],bins=4)
plt.hist(udemy['level'],bins=3)

# %%
import seaborn as sns
sns.kdeplot(udemy['level'])# it gives probability in which region more data is present udemy

# %%
import seaborn as sns

# %%
sns.kdeplot(udemy['level']) # bivariate analysis n-n we are analysing data based on relations among themselves

# %%
udemy.columns

# %%
sns.lineplot(x='course_title',y='is_paid',data=udemy,color='red')
u

# %%
sns.lineplot(x='',y='num_subscribers',data=udemy,color='red')

# %%
udemy.columns

# %%
udemy['level'].value_counts().index[:2]

# %%
# collect only the data where publisher, genre among top 3

# %%
udemy.columns

# %%
udemy['num_subscribers'].value_counts()

# %%
udemy['num_reviews'].value_counts()

# %%
udemy.columns

# %%
t=udemy['course_id'].value_counts().index[:3]
t

# %%
p=udemy['course_title'].value_counts().index[:3]

# %%
r=udemy['num_reviews'].value_counts().index[:3]

# %%
df=udemy[(udemy['course_id'].isin(t))&(udemy['course_title'].isin(p))&(udemy['num_reviews'].isin(r))]

# %%
df  # it will check all conditions weather all are there or not

# %%
udemy[udemy['course_id'].isin(t)]
udemy['course_id'].nunique()

# %%
t

# %%
sns.boxplot(x='course_title',y='num_subscribers',data=udemy)

# %%
sns.countplot(data=df,x='level',)

# %%
udemy.columns

# %%
sns.countplot(x='is_paid',data=udemy)
sns.countplot(x='course_title',hue='subject',data=udemy)

# %%
# in udemy courses paid courses subscribers are more compared to the unpaid courses

# %%
udemy
# Out:
#       course_id                                       course_title  \
# 0       1070968                 Ultimate Investment Banking Course
# 1       1113822  Complete GST Course & Certification - Grow You...
# 2       1006314  Financial Modeling for Business Analysts and C...
# 3       1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4       1011058       How To Maximize Your Profits Trading Options
# ...         ...                                                ...
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 0     https://www.udemy.com/ultimate-investment-bank...     True    200
# ...

# %%
udemy

# %%
sns.boxplot()

# %%
# for each game different genres will be there for each genre how many global sales are there for it

# %%
# for countplot y axis will be count of x axis values

# %%
sns.boxplot(x='categorical column',y='numerical column',data=dataframe name) # for boxplot one categorical and one numerical will
#be there

# %%
sns.barplot(x='categorical column',y='numericalcolumn',data=dataframename,estimator=np.mean) # barplot will take any numerical column for it 
#for one publisher how many number of sales are there for it
# if u dont write any thing means estimator will be mean of it 
# we can put np.max,np.min will be there for it
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2492\516700393.py in <module>
# ----> 1 sns.barplot(x='categorical column',y='numericalcolumn',data=dataframename,estimator=np.mean) # barplot will take any numerical column for it
#       2 #for one publisher how many number of sales are there for it
#       3 # if u dont write any thing means estimator will be mean of it
#       4 # we can put np.max,np.min will be there for it
#
# NameError: name 'dataframename' is not defined

# %%
udemy.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
# 2 rows and 3 columns will be displayed
plt.figure(figsize=(12,15))
plt.subplot(2,3,1)
sns.scatterplot(x='num_reviews',y='num_lectures',data=udemy)
# Out:
# <AxesSubplot:xlabel='num_reviews', ylabel='num_lectures'>

# %%
subplot(2,1,1) # it represents two rows 1 column and one 1 index position of it 
subplot(3,1,2) # it represents 3 rows 1 column and 2nd index position of it 
fig.suptitle('name of graph')
